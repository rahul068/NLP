# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, CuDNNLSTM, LSTM, SpatialDropout1D, GlobalMaxPool1D, Dropout
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from sklearn.utils import resample
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,classification_report
import re
import seaborn as sns
import matplotlib.pyplot as plt
import string

# %%
data = pd.read_csv('./fake-news/train.csv', delimiter=",", encoding='utf-8')

# %%
data.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
data['text'] = data['author'] + " " + data['title'] + " " +  data['text']

# %%
data = data.drop(['id','title','author'],1)
# Out:
# <ipython-input-49-7487443a8a60>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data = data.drop(['id','title','author'],1)

# %%
import re
from typing import List

import spacy
from spacy.tokens import Doc
from tqdm import tqdm


class SpacyPreprocessor:
    def __init__(
        self,
        spacy_model=None,
        remove_numbers=False,
        remove_special=True,
        pos_to_remove=None,
        remove_stopwords=False,
        lemmatize=False,
    ):
        """
        Preprocesses text using spaCy
        :param remove_numbers: Whether to remove numbers from text
        :param remove_stopwords: Whether to remove stopwords from text
        :param remove_special: Whether to remove special characters (including numbers)
        :param pos_to_remove: list of PoS tags to remove
        :param lemmatize:  Whether to apply lemmatization
        """

        self._remove_numbers = remove_numbers
        self._pos_to_remove = pos_to_remove
        self._remove_stopwords = remove_stopwords
        self._remove_special = remove_special
        self._lemmatize = lemmatize

        if not spacy_model:
            self.model = spacy.load("en_core_web_sm")
        else:
            self.model = spacy_model

    @staticmethod
    def download_spacy_model(model="en_core_web_sm"):
        print(f"Downloading spaCy model {model}")
        spacy.cli.download(model)
        print(f"Finished downloading model")

    @staticmethod
    def load_model(model="en_core_web_sm"):
        return spacy.load(model, disable=["ner", "parser"])

    def tokenize(self, text) -> List[str]:
        """
        Tokenize text using a spaCy pipeline
        :param text: Text to tokenize
        :return: list of str
        """
        doc = self.model(text)
        return [token.text for token in doc]

    def preprocess_text(self, text) -> str:
        """
        Runs a spaCy pipeline and removes unwanted parts from text
        :param text: text string to clean
        :return: str, clean text
        """
        doc = self.model(text)
        return self.__clean(doc)

    def preprocess_text_list(self, texts=List[str]) -> List[str]:
        """
        Runs a spaCy pipeline and removes unwantes parts from a list of text.
        Leverages spaCy's `pipe` for faster batch processing.
        :param texts: List of texts to clean
        :return: List of clean texts
        """
        clean_texts = []
        for doc in tqdm(self.model.pipe(texts)):
            clean_texts.append(self.__clean(doc))

        return clean_texts

    def __clean(self, doc: Doc) -> str:

        tokens = []
        # POS Tags removal
        if self._pos_to_remove:
            for token in doc:
                if token.pos_ not in self._pos_to_remove:
                    tokens.append(token)
        else:
            tokens = doc

        # Remove Numbers
        if self._remove_numbers:
            tokens = [
                token for token in tokens if not (token.like_num or token.is_currency)
            ]

        # Remove Stopwords
        if self._remove_stopwords:
            tokens = [token for token in tokens if not token.is_stop]
        # remove unwanted tokens
        tokens = [
            token
            for token in tokens
            if not (
                token.is_punct or token.is_space or token.is_quote or token.is_bracket
            )
        ]

        # Remove empty tokens
        tokens = [token for token in tokens if token.text.strip() != ""]

        # Lemmatize
        if self._lemmatize:
            text = " ".join([token.lemma_ for token in tokens])
        else:
            text = " ".join([token.text for token in tokens])

        if self._remove_special:
            # Remove non alphabetic characters
            text = re.sub(r"[^a-zA-Z\']", " ", text)
        # remove non-Unicode characters
        text = re.sub(r"[^\x00-\x7F]+", "", text)

        text = text.lower()

        return text

# %%
preprocessor = SpacyPreprocessor(remove_numbers=True,
                                 remove_special=True,
#                                 pos_to_remove=True,
                                 remove_stopwords=True,
                                 lemmatize=True)
data['text'] = data['text'].apply(lambda x: preprocessor.preprocess_text(str(x)))

# %%
data.head()
# Out:
#                                                 text  label
# 0  darrell lucus house dem aide we didn’t even se...      1
# 1  daniel j flynn flynn hillary clinton big woman...      0
# 2  consortiumnewscom why the truth might get you ...      1
# 3  jessica purkiss  civilians killed in single us...      1
# 4  howard portnoy iranian woman jailed for fictio...      1

# %%
words = set(" ".join(data['text'].tolist()).split(' '))

# %%
words
# Out:
# {'',
#  'substitute',
#  'maxwel',
#  'lutein',
#  'falla',
#  'cratchette',
#  'wenezuel',
#  'polaroid',
#  'whyatt',
#  'shyer',
#  'votetoday',
#  'creativo',
#  'serlo',
#  'iaf',
#  'kaffiyeh',
#  'overtreatment',
#  'nonstick',
#  'mpft',
#  'fram',
#  'hajaja',
#  'multicity',
#  'frontal',
#  'purine',
#  'exsactly',
#  'portraitist',
#  'lomonte',
#  'venusino',
#  'insolvent',
#  'hockenbury',
#  'madiran',
#  'conducir',
#  'uncontested',
#  'amerisleep',
#  'ndeme',
#  'gallagher',
#  'iaayh',
#  'forfeits',
#  'niebla',
#  'palumbo',
#  'talker',
#  'patronal',
#  'rottentomatoes',
#  'hamlyn',
#  'thirdworldize',
#  'masshole',
#  'enministeriums',
#  'offrir',
#  'obliterate',
#  'kissinger',
#  'injun',
#  'unhealthy',
#  'shishapangma',
#  'bijan',
#  'jamshoro',
#  'precipitant',
#  'johannsson',
#  'berankis',
#  'euler',
#  'wissen',
#  'longo',
#  'decolonization',
#  'poaching',
#  'aliquippa',
#  'bonquita',
#  'yousefi',
#  'llevado',
#  'greenwave',
#  'nullification',
#  'inventer',
#  'swinging',
#  'politicizing',
#  'lauric',
#  'ld',
#  'pretentiously',
#  'terawatt',
#  'emidio',
#  'anbd',
#  'events',
#  'loch',
#  'marjorie',
#  'croaky',
#  'perspiring',
#  'voortkoman',
#  'superinsulated',
#  'pty',
#  'bislang',
#  'abovetopsecret',
#  'staver',
#  'staus',
#  'pookie',
#  'asawin',
#  'salesroom',
#  'clapham',
#  'abhijit',
#  'pocz',
#  'suppression',
#  'hancock',
#  'tarjeta',
#  'chica',
#  'gurkan',
#  'workaround',
#  'astringent',
#  'lagomarsino',
#  'heroization',
#  'sich',
#  'schimelpfenig',
#  'tto',
#  'dontre',
#  'intermarium',
#  'ward',
#  'weegens',
#  'ikhtilat',
#  'shaffer',
#  'irons',
#  'tami',
#  'metaphorically',
#  'obscurantism',
#  'coralie',
#  'zahlreiche',
#  'circumpolar',
#  'edda',
#  'actuara',
#  'breasts',
#  'gebbia',
#  'modulating',
#  'statesmanlike',
#  'anomalousness',
#  'denigrante',
#  'shamma',
#  'kristopher',
#  'noman',
#  'fluke',
#  'scythians',
#  'precipitate',
#  'ethical',
#  'filmfare',
#  'redaktionsassistentin',
#  'everythe',
#  'olmayan',
#  'roguemoney',
#  'eccentric',
#  'zinedine',
#  'elsene',
#  'legalexaminer',
#  'exports',
#  'megabit',
#  'search',
#  'treasurer',
#  'calmer',
#  'draplin',
#  'victimization',
#  'jak',
#  'reignofapril',
#  'sounio',
#  'muhaysini',
#  'lors',
#  'ome',
#  'hep',
#  'walshfreedom',
#  'lkdi',
#  'lisum',
#  'misallocate',
#  'wessler',
#  'broiles',
#  'arranca',
#  'fia',
#  'kallstadt',
#  'spector',
#  'santamar',
#  'picnicker',
#  'twila',
#  'abalone',
#  'vitando',
#  'statewide',
#  'einfach',
#  'sakwa',
#  'ippolito',
#  'mondello',
#  'grasslike',
#  'grier',
#  'funches',
#  'seige',
#  'sarcoma',
#  'overrepresentation',
#  'luis',
#  'scottish',
#  'lurching',
#  'satin',
#  'tolson',
#  'ho',
#  'georgetakei',
#  'agricol',
#  'eurekalert',
#  'carraway',
#  'vigilantly',
#  'hajiya',
#  'alder',
#  'declararla',
#  'millonaria',
#  'ricochet',
#  'lackadaisical',
#  'dull',
#  'ordon',
#  'recycle',
#  'ingestion',
#  'kimche',
#  'metroidvania',
#  'wiatu',
#  'grindstone',
#  'cita',
#  'xpyzbdn',
#  'afirm',
#  'sekizinci',
#  'monday',
#  'izmir',
#  'commercialise',
#  'bedier',
#  'malty',
#  'changey',
#  'masala',
#  'konomisk',
#  'trumppence',
#  'offends',
#  'gacy',
#  'poul',
#  'medinah',
#  'brinker',
#  'adivina',
#  'winters',
#  'debunk',
#  'ohanka',
#  'resueltamente',
#  'bhushan',
#  'miembro',
#  'brav',
#  'brandonmond',
#  'inton',
#  'githyp',
#  'countrys',
#  'hamburguesa',
#  'smartmetereducationnetwork',
#  'breathtakingly',
#  'plainest',
#  'implementarla',
#  'vehicles',
#  'ldl',
#  'worldly',
#  'lingerie',
#  'sickest',
#  'conformar',
#  'reasonably',
#  'ovitz',
#  'girlishness',
#  'haly',
#  'irme',
#  'cuelga',
#  'hardball',
#  'nicho',
#  'lucroy',
#  'enhancing',
#  'exuma',
#  'ioulia',
#  'villalobos',
#  'skovorodino',
#  'muhlig',
#  'dissociative',
#  'brandet',
#  'dialogue',
#  'spitze',
#  'pgen',
#  'heuchelei',
#  'reaksjon',
#  'renews',
#  'avangrid',
#  'solemnity',
#  'musk',
#  'directionless',
#  'burkha',
#  'kaust',
#  'declaration',
#  'versatility',
#  'hackism',
#  'friar',
#  'policeman',
#  'backslid',
#  'squeeze',
#  'jlr',
#  'palace',
#  'precursor',
#  'hamiltonian',
#  'ggas',
#  'prednisone',
#  'medipen',
#  'norrmalmstorg',
#  'aldon',
#  'pflicht',
#  'memorizing',
#  'mutli',
#  'timed',
#  'enstupidation',
#  'the',
#  'beziers',
#  'demonetize',
#  'impassive',
#  'worauf',
#  'shafir',
#  'stanislav',
#  'populated',
#  'gibbons',
#  'sangatte',
#  'macallah',
#  'sitios',
#  'bilmes',
#  'storyk',
#  'shangh',
#  'montinore',
#  'calving',
#  'bartella',
#  'pernicious',
#  'threat',
#  'wring',
#  'devante',
#  'drezen',
#  'redstatewatcher',
#  'unerh',
#  'lovett',
#  'perd',
#  'erda',
#  'calatrava',
#  'lister',
#  'oversize',
#  'azes',
#  "s'il",
#  'cypress',
#  'moweek',
#  'wilw',
#  'carriedbygrace',
#  'damon',
#  'eversole',
#  'leblanc',
#  'lilia',
#  'flock',
#  'pensioner',
#  'forgave',
#  'jackiedstrause',
#  'midlevel',
#  'whippoorwills',
#  'spratt',
#  'coders',
#  'perquisite',
#  'lendi',
#  'nyjusticeleague',
#  'elysian',
#  'pepe',
#  'dreary',
#  'kapur',
#  'abgebildet',
#  'teniendo',
#  'fyodor',
#  'remedial',
#  'mergens',
#  'realistas',
#  'rambourg',
#  'prioritaria',
#  'martian',
#  'raban',
#  'obersten',
#  'joanr',
#  'billion',
#  'ezzat',
#  'deviance',
#  'cinsiyetine',
#  'mathies',
#  'tashfeen',
#  'aaluijqn',
#  'doke',
#  'revocable',
#  'kissito',
#  'krajnc',
#  'fortalde',
#  'freaks',
#  'tyee',
#  'transitions',
#  'euskal',
#  'dritte',
#  "n'a",
#  'southeast',
#  'nichtstaatlichen',
#  'lesquels',
#  'infestations',
#  'rapidement',
#  'wizened',
#  'overperforme',
#  'tortuously',
#  'leisten',
#  'havegunwilltravel',
#  'marvellous',
#  'horia',
#  'tephi',
#  'anticonvulsant',
#  'illegalmente',
#  'transici',
#  'thoughtless',
#  'ching',
#  'sumlin',
#  'histrionic',
#  'sipher',
#  'sabril',
#  'subversiveness',
#  'impregnate',
#  'skanky',
#  'fernham',
#  'bewijs',
#  'compounds',
#  'applicant',
#  'darkostojanovic',
#  'pasa',
#  'occupancy',
#  'annalyn',
#  'conspire',
#  'fdr',
#  'colegir',
#  'passaic',
#  'cobain',
#  'mousse',
#  'brassage',
#  'hamam',
#  'alonzo',
#  'outdoorsy',
#  'ebbs',
#  'annuity',
#  'goucher',
#  'medea',
#  'nathanial',
#  'vilify',
#  'crapified',
#  'ames',
#  'mankiw',
#  'induce',
#  'peccadillo',
#  'syrians',
#  'klean',
#  'trust',
#  'haag',
#  'lograr',
#  'monclova',
#  'kanl',
#  'punctuation',
#  'judd',
#  'gaudet',
#  'wuthering',
#  'kawartha',
#  'glittering',
#  'typewriter',
#  'cordon',
#  'opone',
#  'araba',
#  'quasimodo',
#  'rennen',
#  'assumedly',
#  'ghat',
#  'voshell',
#  'implicaci',
#  'provenance',
#  'beauts',
#  'ersoy',
#  'klausner',
#  'overreact',
#  'depart',
#  'bruhl',
#  'lessing',
#  'ngp',
#  'enforcement',
#  'bandwagon',
#  'creepiness',
#  'zhukova',
#  'merklichen',
#  'administered',
#  'discreetness',
#  'killion',
#  'proficiency',
#  'abendessen',
#  'visualizer',
#  'hanya',
#  'orthodoxen',
#  'subtweet',
#  'forcejea',
#  'kevlar',
#  'janas',
#  'disinfo',
#  'broadness',
#  'burgaud',
#  'pulpiteering',
#  'schwachen',
#  'hush',
#  'utilizaci',
#  'matzu',
#  'subjectivism',
#  'austenalia',
#  'mujhe',
#  'msh',
#  'coraz',
#  'incredibility',
#  'raiders',
#  'sluts',
#  'mandino',
#  'amtrak',
#  'wemeantwell',
#  'erupcj',
#  'plaything',
#  'gastonguay',
#  'reptile',
#  'precisamente',
#  'enthronization',
#  'beauftragen',
#  'conspiracionista',
#  'bamboozled',
#  'aberration',
#  'condone',
#  'proposici',
#  'polish',
#  'jansson',
#  'wheeze',
#  'generalistic',
#  'perp',
#  'dahlkvist',
#  'thirdly',
#  'muladhara',
#  'barr',
#  'rerecorded',
#  'harekete',
#  'sportsfunhouse',
#  'whitewashed',
#  'ghadir',
#  'oahe',
#  'firebombs',
#  'unfinished',
#  'deirdre',
#  'sslich',
#  'tamler',
#  'tomllamasabc',
#  'penalize',
#  'farag',
#  'infrastrucutre',
#  'reckless',
#  'highbridge',
#  'muffle',
#  'curtin',
#  'roseanne',
#  'strata',
#  'berniecrats',
#  'nuked',
#  'dumb',
#  'notable',
#  'kilimnik',
#  'casoria',
#  'turkovich',
#  'huskey',
#  'karic',
#  'wirtschafts',
#  'pasarme',
#  'balen',
#  'minuteness',
#  'bicarbonate',
#  'tirer',
#  'responderle',
#  'theatlantic',
#  'oloroso',
#  'dales',
#  'xbfyqooo',
#  'zosia',
#  'scholarly',
#  'cpzochyhsvgppzyh',
#  'sajmir',
#  'ganyata',
#  'dysregulate',
#  'fontanella',
#  'samimi',
#  'schlagkr',
#  'superhuman',
#  'jamieleecurtis',
#  'encouraged',
#  'steele',
#  'jawetz',
#  'cekic',
#  'allegations',
#  'ludzi',
#  'comp',
#  'ukie',
#  'munn',
#  'jzws',
#  'urinate',
#  'revengeance',
#  'cowy',
#  'moiseyev',
#  'comunidades',
#  'dvorkovich',
#  'deliberations',
#  'peri',
#  'thresholds',
#  'voll',
#  'morphology',
#  'doctorate',
#  'nonmetallic',
#  'epictetus',
#  'guggenheim',
#  'fissure',
#  'acting',
#  'tuckman',
#  'sedasso',
#  'historischer',
#  'mullainathan',
#  'mathematically',
#  'unrelievedly',
#  'syl',
#  'allende',
#  'engelleri',
#  'sandstrom',
#  'secessionary',
#  'gracious',
#  'majorna',
#  'hiiumaa',
#  'aikido',
#  'possibilmente',
#  'iliad',
#  'disgusto',
#  'churchyard',
#  'joze',
#  'rompi',
#  'mam',
#  'katko',
#  'deniega',
#  'bargain',
#  'quittner',
#  'forbiddingly',
#  'footsoldier',
#  'ethnocentric',
#  'expireddomains',
#  'caffeine',
#  'shitshow',
#  'hil',
#  'uzakla',
#  'insatiable',
#  'anapali',
#  'crystalize',
#  'inches',
#  'staatlichen',
#  'karachay',
#  'eilperin',
#  'cheesemaker',
#  'evac',
#  'compromised',
#  'kodaka',
#  'knoller',
#  'evitarle',
#  'partiality',
#  'wahdat',
#  'patronato',
#  'boob',
#  'louima',
#  'corgi',
#  'rbi',
#  'interestings',
#  'pare',
#  'trieu',
#  'medscape',
#  'liberdade',
#  'toddyo',
#  'cultist',
#  'unsettling',
#  'corinne',
#  'organiserte',
#  'noreste',
#  'rori',
#  'gyory',
#  'argetsinger',
#  'socialista',
#  'grabber',
#  'mallory',
#  'creature',
#  'intune',
#  'relman',
#  'rner',
#  'kramerbooks',
#  'giles',
#  'shawn',
#  'hellish',
#  'meddling',
#  'gloe',
#  'generalizado',
#  'minim',
#  'predicate',
#  'skatell',
#  'pilotless',
#  'zuckerman',
#  'commodities',
#  'vamc',
#  'wiecznej',
#  'fpreventdisease',
#  'debuff',
#  'jahweh',
#  'zang',
#  'jericho',
#  'lausd',
#  'senegal',
#  'gerrick',
#  'humanitaire',
#  'solden',
#  'denominate',
#  'turkman',
#  'dizzying',
#  'cigarrillos',
#  'caucusing',
#  'ferreira',
#  'nipper',
#  'exec',
#  'baha',
#  'shamima',
#  'nitzan',
#  'dimicco',
#  'serbian',
#  'truthseeker',
#  'rightwing',
#  'ismayilova',
#  'flushing',
#  'asme',
#  'erupt',
#  'guzzler',
#  'creyeran',
#  'cnnpr',
#  'malmstr',
#  'transience',
#  'sunroofs',
#  'shives',
#  'labaton',
#  'pommard',
#  'beschlagnahmte',
#  'colectiva',
#  'anthonyfreda',
#  'annually',
#  'restricting',
#  'supercomputer',
#  'foodie',
#  'decosmo',
#  'gasser',
#  'matur',
#  'quadcopter',
#  'jg',
#  'ores',
#  'avelar',
#  'tayanj',
#  'magnier',
#  'faturechi',
#  'undertegnet',
#  'monets',
#  'acrimony',
#  'deprogramed',
#  'physiognomy',
#  'certificado',
#  'wrangling',
#  'selvi',
#  'ravenal',
#  'induced',
#  'turbocharged',
#  'nazaire',
#  'garroutte',
#  'kole',
#  'bondmageddon',
#  'labelling',
#  'tumbledown',
#  'caba',
#  'dun',
#  'acelam',
#  'zytsov',
#  'nube',
#  'dfa',
#  'labin',
#  'mgs',
#  'marsay',
#  'mexifornia',
#  'falsificaci',
#  'agobiante',
#  'metodistas',
#  'wattsupwiththat',
#  'steamy',
#  'vanishes',
#  'ripulito',
#  'tained',
#  'birka',
#  'doorway',
#  'kemble',
#  'nombres',
#  'jeffkbell',
#  'embroil',
#  'plangent',
#  'nestazhe',
#  'activation',
#  'talton',
#  'alec',
#  'automakers',
#  'gorky',
#  'proofread',
#  'cour',
#  'carvacrol',
#  'trovati',
#  'plepler',
#  'ruoff',
#  'normalness',
#  'activating',
#  'immolation',
#  'golota',
#  'acx',
#  'monast',
#  'deception',
#  'importuning',
#  'beak',
#  'disesteem',
#  'vanengelsdorp',
#  'laney',
#  'teitz',
#  'cuerda',
#  'danielgcolina',
#  'arcata',
#  'diesmal',
#  'apteligent',
#  'purposeful',
#  'scheduling',
#  'played',
#  'lymphomyosot',
#  'hobbling',
#  'aulas',
#  'humane',
#  'steingart',
#  'ankylose',
#  'nuance',
#  'kalergi',
#  'pazira',
#  'volkswirtschaften',
#  'arisen',
#  'alpharetta',
#  'acct',
#  'igh',
#  'captive',
#  'geographically',
#  'higkeiten',
#  'toughest',
#  'titty',
#  'validity',
#  'throbby',
#  'happer',
#  'studious',
#  'wippte',
#  'wzpqcoaajqvz',
#  'rgern',
#  'lessee',
#  'sluggishness',
#  'steadfast',
#  'serion',
#  'exponentially',
#  'fister',
#  'sigourney',
#  'empuje',
#  'viceland',
#  'hyster',
#  'elkayam',
#  'bedbedbedbedbed',
#  'wii',
#  'parral',
#  'shkolnik',
#  'backus',
#  'thud',
#  'isler',
#  'younis',
#  'mantello',
#  'zweizimmerwohnung',
#  'midlife',
#  'yamiche',
#  'struyk',
#  'retract',
#  'plainer',
#  'hauler',
#  'pathophysiological',
#  'detectably',
#  'arribismo',
#  'neuschwabenland',
#  'pharmaceutic',
#  'lat',
#  'shani',
#  'dionysian',
#  'myrdal',
#  'ap',
#  'contra',
#  'cartel',
#  'lww',
#  'kval',
#  'mineralsestimated',
#  'suffuse',
#  'islander',
#  'badda',
#  'expository',
#  'spaceplane',
#  'showcases',
#  'psychocandy',
#  'brytyjskiego',
#  'nonconditional',
#  'perring',
#  'sunnyvale',
#  'seaborn',
#  'columpio',
#  'petco',
#  'fiend',
#  'capitalistic',
#  'herdener',
#  'pom',
#  'progressives',
#  'ruedo',
#  'reckitt',
#  'sportsmanship',
#  'falsifica',
#  'guerami',
#  'inozemtseva',
#  'bowne',
#  'articulation',
#  'locklear',
#  'thursday',
#  'gainsay',
#  'verte',
#  'motherless',
#  'filibuster',
#  'pritha',
#  'puli',
#  'endearing',
#  'propranolol',
#  'somtime',
#  'violating',
#  'harrp',
#  'reimplante',
#  'kumandal',
#  'agrarian',
#  'armour',
#  'corroborate',
#  'peevish',
#  'standingwithstandingrock',
#  'papkin',
#  'pta',
#  'palabras',
#  'stretches',
#  'anguera',
#  'grushevsky',
#  'true',
#  'mattdelpiano',
#  'invigilate',
#  'silvesternacht',
#  'usw',
#  'quintabe',
#  'redflag',
#  'unencrypted',
#  'strategy',
#  'ismaily',
#  'membres',
#  'longggg',
#  'taha',
#  'schuldensuehner',
#  'standard',
#  'qwz',
#  'lorry',
#  'sel',
#  'obergefell',
#  'balfour',
#  'rabbishmuley',
#  'obliga',
#  'hairdresser',
#  'zeferino',
#  'grushevskogo',
#  'organisierte',
#  'rastrelli',
#  'chiron',
#  'weintraub',
#  'mendacium',
#  'kofi',
#  'amol',
#  'significantly',
#  'dobbin',
#  'phyllida',
#  'underwent',
#  'glichst',
#  'secrete',
#  'seelig',
#  'campa',
#  'gwinn',
#  'connallys',
#  'dengler',
#  'alanlar',
#  'mccaw',
#  'congr',
#  'foole',
#  'interm',
#  'cellulose',
#  'jmi',
#  'dethick',
#  ...}

# %%
data['wordCount'] = data['text'].str.split().str.len() # Populating work count per news

# %%
max_features = len(words) # Number of distinct words in news 
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(data['text'].values)
X = tokenizer.texts_to_sequences(data['text'].values)
#X_test = tokenizer.texts_to_sequences(testData['comment_text'].values)
X = pad_sequences(X)
#X_test = pad_sequences(X_test)

# %%
# Out:
# array([[    0,     0,     0, ..., 13955, 25504,  1248],
#        [    0,     0,     0, ...,  1682,   945,  7230],
#        [    0,     0,     0, ...,   256,  1508,  6413],
#        ...,
#        [    0,     0,     0, ...,  3416,  2865,   611],
#        [    0,     0,     0, ...,  2256,  1388,  2804],
#        [    0,     0,     0, ..., 14365,  1818,  1714]], dtype=int32)

# %%
maxlen = max(data['wordCount']) # max number of words per news   
embed_dim = 128
model = Sequential([
    Embedding(input_dim=max_features, output_dim=embed_dim, 
                              input_length=maxlen),
    LSTM(60, return_sequences=True),
    GlobalMaxPool1D(),
    Dropout(0.1),
    Dense(50, activation='relu'),
    Dropout(0.1),
    Dense(1, activation='sigmoid')])    # only 2 value in each labels

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# using binary crossentropy because each labels or the features only have 2 value, 0 or 1

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 10578, 128)        16590208
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10578, 60)         45360
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 60)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 60)                0
# _________________________________________________________________
# dense (Dense)                (None, 50)                3050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 306
# =================================================================
# Total params: 16,638,924
# Trainable params: 16,638,924
# Non-trainable params: 0
# _________________________________________________________________

# %%
Y = data[['label']]

# %%
batch_size = 128
model.fit(X, Y, epochs = 10, batch_size=batch_size, verbose = 1)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-e5fc2aefdc0d> in <module>
#       1 batch_size = 128
# ----> 2 model.fit(X, Y, epochs = 10, batch_size=batch_size, verbose = 1)
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1156                 _r=1):
#    1157               callbacks.on_train_batch_begin(step)
# -> 1158               tmp_logs = self.train_function(iterator)
#    1159               if data_handler.should_sync:
#    1160                 context.async_wait()
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     922       # In this case we have not created variables on the first call. So we can
#     923       # run the first trace but we should fail if variables are created.
# --> 924       results = self._stateful_fn(*args, **kwds)
#     925       if self._created_variables:
#     926         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3020     with self._lock:
#    3021       (graph_function,
# -> 3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3438               self.input_signature is None and
#    3439               call_context_key in self._function_cache.missed):
# -> 3440             return self._define_function_with_shape_relaxation(
#    3441                 args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3442
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3360           expand_composites=True)
#    3361
# -> 3362     graph_function = self._create_graph_function(
#    3363         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3364     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     984           except Exception as e:  # pylint:disable=broad-except
#     985             if hasattr(e, "ag_error_metadata"):
# --> 986               raise e.ag_error_metadata.to_exception(e)
#     987             else:
#     988               raise
#
# ValueError: in user code:
#
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py:830 train_function  *
#         return step_function(self, iterator)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py:813 run_step  *
#         outputs = model.train_step(data)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/training.py:771 train_step  *
#         loss = self.compiled_loss(
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/engine/compile_utils.py:201 __call__  *
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/losses.py:142 __call__  *
#         losses = call_fn(y_true, y_pred)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/losses.py:246 call  *
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:206 wrapper  **
#         return target(*args, **kwargs)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/losses.py:1741 binary_crossentropy
#         backend.binary_crossentropy(
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:206 wrapper
#         return target(*args, **kwargs)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/keras/backend.py:4988 binary_crossentropy
#         return tf.compat.v1.nn.sigmoid_cross_entropy_with_logits(labels=target, logits=output)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:206 wrapper
#         return target(*args, **kwargs)
#     /usr/local/Caskroom/miniforge/base/lib/python3.9/site-packages/tensorflow/python/ops/nn_impl.py:132 sigmoid_cross_entropy_with_logits
#         raise ValueError("logits and labels must have the same shape (%s vs %s)" %
#
#     ValueError: logits and labels must have the same shape ((None, 6) vs (None, 1))

# %%
len(X)
# Out:
# 20800

# %%
len(Y)
# Out:
# 20800
